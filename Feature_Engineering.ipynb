# %% [markdown]
# 1. What is a parameter?
# -->A parameter is a value that defines a characteristic of a model or function. It is used to control the behavior of the model.
#
# 2. What is correlation?What does negative correlation mean?
#
# -->Correlation measures the relationship between two variables, indicating how one variable changes with respect to the other.
#
# Negative correlation means that as one variable increases, the other variable decreases.
#
# 3. Define Machine Learning. What are the main components in Machine Learning?
#
# -->Machine Learning is a field of AI that enables computers to learn from data and make predictions. Main components are:
# - Data
# - Algorithms
# - Model
# - Training
# - Evaluation
#
# 4. How does loss value help in determining whether the model is good or not?
#
# -->Loss value measures the difference between the predicted and actual values. A lower loss value indicates a better model.
#
# 5. What are continuous and categorical variables?
#
# --> **Continuous Variables**: Variables that can take any value within a range (e.g., height, weight).
# - **Categorical Variables**: Variables that represent categories or groups (e.g., gender, color).
#
# 6. How do we handle categorical variables in Machine Learning? What are the common techniques?
#
# -->Common techniques to handle categorical variables are:
# - One-Hot Encoding
# - Label Encoding
#
# 7. What do you mean by training and testing a dataset?
#
# -->Training a dataset means using it to teach the model. Testing a dataset means evaluating the model's performance on unseen data.
#
# 8. What is sklearn.preprocessing?
#
# -->`sklearn.preprocessing` is a module in scikit-learn that provides tools for data preprocessing, such as scaling and encoding.
#
# 9. What is a Test set?
#
# -->A test set is a subset of data used to evaluate the performance of a trained model.
#
# 10. How do we split data for model fitting (training and testing) in Python?How do you approach a Machine Learning problem?
#
# -->We use `train_test_split` from `sklearn.model_selection` to split data into training and testing sets.
#
#  approach for Machine Learning problem
#
#  >Define the problem
#
#  >Collect and preprocess data
#
#  >Choose a model
#
#  >Train the model
#
#  >Evaluate the model
#
#  >Tune the model
#
#  >Deploy the model
#
# 11. Why do we have to perform EDA before fitting a model to the data?
#
# -->Exploratory Data Analysis (EDA) helps understand the data, identify patterns, and detect anomalies, ensuring better model performance.
#
# 12. What is correlation?
#
# -->Correlation measures the relationship between two variables, indicating how one variable changes with respect to the other.
#
# 13. What does negative correlation mean?
#
# -->Negative correlation means that as one variable increases, the other variable decreases.
#
# 14. How can you find correlation between variables in Python?
#
# -->Use `corr()` method in pandas or `pearsonr()` from `scipy.stats`.
#
# 15. What is causation? Explain difference between correlation and causation with an example.
#
# -->Causation means one event causes another. Correlation means two events are related but not necessarily causal.
# **Example**: Ice cream sales and drowning rates are correlated but not causally related.
#
# 16. What is an Optimizer? What are different types of optimizers? Explain each with an example.
#
# -->An optimizer adjusts model parameters to minimize the loss function.
# - **SGD (Stochastic Gradient Descent)**: Updates parameters using a small batch of data.
# - **Adam**: Combines the advantages of two other extensions of stochastic gradient descent.
#
# 17. What is sklearn.linear_model?
#
# -->`sklearn.linear_model` is a module in scikit-learn that provides linear models for regression and classification.
#
# 18. What does model.fit() do? What arguments must be given?
#
# -->`model.fit()` trains the model on the given data. Arguments: training data (X) and target values (y).
#
# 19. What does model.predict() do? What arguments must be given?
#
# -->`model.predict()` makes predictions using the trained model. Arguments: input data (X).
#
# 20. What are continuous and categorical variables?
#
# -->- **Continuous Variables**: Variables that can take any value within a range (e.g., height, weight).
# - **Categorical Variables**: Variables that represent categories or groups (e.g., gender, color).
#
# 21. What is feature scaling? How does it help in Machine Learning?
#
# -->Feature scaling normalizes data to a standard range, improving model performance and convergence speed.
#
# 22. How do we perform scaling in Python?
#
# -->Use `StandardScaler` or `MinMaxScaler` from `sklearn.preprocessing`.
#
# 23. What is sklearn.preprocessing?
#
# -->`sklearn.preprocessing` is a module in scikit-learn that provides tools for data preprocessing, such as scaling and encoding.
#
# 24. How do we split data for model fitting (training and testing) in Python?
#
# -->We use `train_test_split` from `sklearn.model_selection` to split data into training and testing sets.
#
# 25. Explain data encoding?
#
# -->Data encoding converts categorical data into numerical format. Common techniques include One-Hot Encoding and Label Encoding.
